# %%
from matplotlib import pylab as plt
# %matplotlib inline

# %%
k=0.2
x = [i for i in range(1,50,1)]
y = [i**(-k) for i in range(1,50,1)]
plt.plot(x,y)

# %%
k=0.5
x = [i for i in range(1,50,1)]
y = [i**(-k) for i in range(1,50,1)]
plt.plot(x,y)

# %%
k=1
x = [i for i in range(1,50,1)]
y = [i**(-k) for i in range(1,50,1)]
plt.plot(x,y)

# %%
k=2
x = [i for i in range(1,50,1)]
y = [i**(-k) for i in range(1,50,1)]
plt.plot(x,y)

# %%
k=3
x = [i for i in range(1,50,1)]
y = [i**(-k) for i in range(1,50,1)]
plt.plot(x,y)

# %%
import numpy as np

# %%
k=0.4
x = [i for i in np.arange(1,50,0.05)]
y = [i**(-k) for i in np.arange(1,50,0.05)]
plt.plot(x,y)

# %%
k=0.8
x = [i for i in np.arange(1,50,0.05)]
y = [i**(-k) for i in np.arange(1,50,0.05)]
plt.plot(x,y)

# %%
k=1
x = [i for i in np.arange(1,50,0.05)]
y = [i**(-k) for i in np.arange(1,50,0.05)]
plt.plot(x,y)

# %%
k=2
x = [i for i in np.arange(1,50,0.05)]
y = [i**(-k) for i in np.arange(1,50,0.05)]
plt.plot(x,y)

# %%
k=2.5
x = [i for i in np.arange(1,50,0.05)]
y = [i**(-k) for i in np.arange(1,50,0.05)]
plt.plot(x,y)

# %%
k=2.5
x = [i for i in np.arange(1,50,0.01)]
y = [i**(-k) for i in np.arange(1,50,0.01)]
plt.plot(x,y)

# %%
k=3
x = [i for i in np.arange(1,50,0.01)]
y = [i**(-k) for i in np.arange(1,50,0.01)]
plt.plot(x,y)

# %%
k=3.5
x = [i for i in np.arange(1,50,0.01)]
y = [i**(-k) for i in np.arange(1,50,0.01)]
plt.plot(x,y)
